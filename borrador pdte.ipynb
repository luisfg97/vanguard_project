# %%
df_final_web_data['date_time_row1'] = df_final_web_data['date_time'].shift(-1)
df_final_web_data

# %%
df_final_web_data['duration'] = df_final_web_data['date_time'] - df_final_web_data['date_time_row1']

# %%
df_final_web_data['duration'] = df_final_web_data['duration'].where(df_final_web_data['visit_id'] == df_final_web_data['visit_id'].shift(-1))
